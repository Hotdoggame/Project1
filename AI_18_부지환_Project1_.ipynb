# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 0s (20.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 🕹️ Data Description
#
# Name : 게임의 이름입니다.
#
#
# Platform : 게임이 지원되는 플랫폼의 이름입니다.
#
#
#
# Year : 게임이 출시된 연도입니다.
#
#
# Genre : 게임의 장르입니다.
#
#
# Publisher : 게임을 배급한 회사입니다.
#
#
# NA_Sales : 북미지역에서의 출고량입니다.
#
#
# EU_Sales : 유럽지역에서의 출고량입니다.
#
#
# JP_Sales : 일본지역에서의 출고량입니다.
#
#
# Other_Sales : 기타지역에서의 출고량입니다.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-caf807ab-57f1-4231-862e-a89ac2fe2926" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-caf807ab-57f1-4231-862e-a89ac2fe2926">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Game_df = pd.read_csv('vgames2.csv')
Game_df[(Game_df['Year'].isnull() == True) | (Game_df['Genre'].isnull() == True) | (Game_df['Publisher'].isnull() == True)]
# Out:
#        Unnamed: 0                                         Name Platform  \
# 31             32                                    Rock Band     X360
# 50             51                     Ape Escape: On the Loose      PSP
# 109           110   Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii
# 272           273                           UK Truck Simulator       PC
# 273           274  Jewel Link Chronicles: Mountains of Madness       DS
# ...           ...                                          ...      ...
# 16425       16426                               Yoostar on MTV     X360
# 16431       16432            Cars: Mater-National Championship     X360
# 16432       16433                                  Bejeweled 3     X360
# 16555       16556                          Apache: Air Assault       PC
# 16587       16588                 Need for Speed Underground 2       XB
#
#          Year       Genre                    Publisher NA_Sales EU_Sales  \
# ...

# %%
Game_df[Game_df['NA_Sales'].str.contains('K')]
# Out:
#        Unnamed: 0                                            Name Platform  \
# 10             11                                     Ford Racing       PS
# 45             46                    Resident Evil: Revelations 2      PS3
# 145           146                              TOCA Race Driver 3       PC
# 878           879  Tears to Tiara Anecdotes: The Secret of Avalon      PS3
# 1086         1087                       Pro Evolution Soccer 2014      3DS
# ...           ...                                             ...      ...
# 15647       15648                       Championship Manager 2010       PC
# 16194       16195                            Vin Diesel: Wheelman      PS3
# 16330       16331                         Midway Arcade Treasures      PS2
# 16492       16493                                   Mortal Kombat      PSV
# 16578       16579                            Gex: Enter the Gecko       PS
#
# ...

# %%
df = pd.read_csv('vgames2.csv')
df.head()
# Out:
#    Unnamed: 0                                            Name Platform  \
# 0           1                    Candace Kane's Candy Factory       DS
# 1           2                                  The Munchables      Wii
# 2           3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3           4                Deal or No Deal: Special Edition       DS
# 4           5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
#
#      Year      Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# 0  2008.0     Action           Destineer     0.04        0        0
# 1  2009.0     Action  Namco Bandai Games     0.17        0        0
# 2  2010.0  Adventure           Alchemist        0        0     0.02
# 3  2010.0       Misc           Zoo Games     0.04        0        0
# 4  2010.0   Platform         D3Publisher     0.12     0.09        0
#
#   Other_Sales
# 0           0
# 1        0.01
# 2           0
# 3           0
# 4        0.04

# %%
df[df.duplicated(subset=['Name', 'Platform'], keep=False)].sort_values(by='Name')
# Out:
#        Unnamed: 0                         Name Platform    Year     Genre  \
# 7346         7347                Madden NFL 13      PS3  2012.0    Sports
# 8717         8718                Madden NFL 13      PS3  2012.0    Sports
# 1318         1319  Need for Speed: Most Wanted     X360  2012.0    Racing
# 2673         2674  Need for Speed: Most Wanted       PC  2005.0    Racing
# 12529       12530  Need for Speed: Most Wanted     X360  2005.0    Racing
# 13808       13809  Need for Speed: Most Wanted       PC  2012.0    Racing
# 8651         8652           Sonic the Hedgehog      PS3     NaN  Platform
# 15705       15706           Sonic the Hedgehog      PS3  2006.0  Platform
# 8055         8056  Wii de Asobu: Metroid Prime      Wii     NaN   Shooter
# 9184         9185  Wii de Asobu: Metroid Prime      Wii     NaN   Shooter
#
#              Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 7346   Electronic Arts     2.11     0.23        0        0.22
# ...

# %%
df[df['Name'] == 'Madden NFL 13']
# Out:
#        Unnamed: 0           Name Platform    Year   Genre        Publisher  \
# 4838         4839  Madden NFL 13     X360  2012.0  Sports  Electronic Arts
# 5288         5289  Madden NFL 13     WiiU  2012.0  Sports  Electronic Arts
# 7346         7347  Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 8717         8718  Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 9504         9505  Madden NFL 13      PSV  2012.0  Sports  Electronic Arts
# 11995       11996  Madden NFL 13      Wii  2012.0  Sports  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 4838      2.53     0.16        0        0.17
# 5288      0.22        0        0        0.02
# 7346      2.11     0.23        0        0.22
# 8717         0     0.01        0           0
# 9504       0.3        0        0        0.03
# 11995     0.51        0        0        0.03

# %%
df = df.drop(8717, axis=0)

# %%
df[df['Name'] == 'Madden NFL 13']
# Out:
#        Unnamed: 0           Name Platform    Year   Genre        Publisher  \
# 4838         4839  Madden NFL 13     X360  2012.0  Sports  Electronic Arts
# 5288         5289  Madden NFL 13     WiiU  2012.0  Sports  Electronic Arts
# 7346         7347  Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 8717         8718  Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 9504         9505  Madden NFL 13      PSV  2012.0  Sports  Electronic Arts
# 11995       11996  Madden NFL 13      Wii  2012.0  Sports  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 4838      2.53     0.16        0        0.17
# 5288      0.22        0        0        0.02
# 7346      2.11     0.23        0        0.22
# 8717         0     0.01        0           0
# 9504       0.3        0        0        0.03
# 11995     0.51        0        0        0.03

# %%
df = df.reset_index(drop=True)

# %%
df['EU_Sales'].loc[7346] = '0.24'
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df['EU_Sales'].loc[7346]
# Out:
# '0.24'

# %%
df = df.drop('Unnamed: 0',axis=1)

# %% [markdown]
# 데이터프레임 필요 없는 Unnamed: 0 제거함

# %%
df['Platform'].unique()
# Out:
# array(['DS', 'Wii', 'PSP', 'PS3', 'PC', 'PS', 'GBA', 'PS4', 'PS2', 'XB',
#        'X360', 'GC', '3DS', '2600', 'SAT', 'GB', 'NES', 'DC', 'N64',
#        'XOne', 'SNES', 'WiiU', 'PSV', 'GEN', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['Genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Misc', 'Platform', 'Sports', 'Simulation',
#        'Racing', 'Role-Playing', 'Puzzle', 'Strategy', 'Fighting',
#        'Shooter', nan], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16598 non-null  int64
#  1   Name         16598 non-null  object
#  2   Platform     16598 non-null  object
#  3   Year         16327 non-null  float64
#  4   Genre        16548 non-null  object
#  5   Publisher    16540 non-null  object
#  6   NA_Sales     16598 non-null  object
#  7   EU_Sales     16598 non-null  object
#  8   JP_Sales     16598 non-null  object
#  9   Other_Sales  16598 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
df['NA_Sales'].unique()
# Out:
# array(['0.04', '0.17', '0', '0.12', '0.02', '0.07', '480K', '0.14',
#        '0.01', '0.57', '0.06', '0.08', '0.48', '0.03', '0.05', '1.93',
#        '0.29', '0.19', '0.3', '0.26', '0.11', '0.18', '0.33', '0.51',
#        '60K', '0.13', '0.52', '0.34', '0.25', '0.41', '0.22', '0.35',
#        '0.1', '0.67', '0.59', '0.36', '0.21', '1.19', '5.91', '1.98',
#        '0.09', '0K', '0.5', '0.94', '0.16', '0.63', '0.43', '0.2', '1.23',
#        '0.44', '0.42', '0.97', '2.67', '0.28', '6.05', '0.47', '0.49',
#        '0.62', '0.24', '0.72', '1.74', '0.46', '0.65', '0.32', '1.53',
#        '0.23', '0.53', '0.37', '1.26', '0.39', '0.58', '1.94', '2.31',
#        '1.03', '0.82', '0.4', '0.93', '0.56', '0.96', '1.64', '0.69',
#        '1.25', '0.27', '0.92', '0.58M', '1.24', '0.25M', '0.86', '0.73',
#        '0.55', '1.54', '1.02', '1.27', '0.54', '0.15', '1.09', '3.44',
#        '2.29', '0.88', '5.55M', '1.37', '2.3', '0.99', '1.15', '0.98',
# ...

# %%
df[df['Publisher'] == 'Unknown']
# Out:
#                                              Name Platform    Year  \
# 30                    Kids Learn Music A+ Edition       DS  2011.0
# 109    Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN
# 212                            Wild West Shootout      Wii  2010.0
# 358            Majesty 2: The Fantasy Kingdom Sim     X360     NaN
# 387                         Gummy Bears Mini Golf      Wii  2010.0
# ...                                           ...      ...     ...
# 16400                                      Afrika      PS3  2008.0
# 16402                               The Golf Club     XOne  2014.0
# 16425                              Yoostar on MTV     X360     NaN
# 16432                                 Bejeweled 3     X360     NaN
# 16500                    The Dark Hills of Cherai       PC  2009.0
#
#             Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 30           Misc   Unknown     0.05        0        0           0
# ...

# %% [markdown]
# 1.  결측치를 보면 다른 값으로 대체할 수 있는가 보면 그런 것은 아닌 거 같다. 일일히 데이터를 찾아가면서 변경하는 것은 시간적으로 무리가 있으며 다른 column과 비교 값으로 대체할 가능성이 없기 때문에 제거하는 것이 좋고 publisher를 보니 Unknown이 존재해 이도 제거하는 것이 좋음.

# %%
df = df[(df['Year'].isnull() == False) & (df['Genre'].isnull() == False) & (df['Publisher'].isnull() == False)]

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df = df[(df['Publisher'] == 'Unknown') == False]

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# 여기까지 결측치 제거함

# %%
df['NA_Sales'].describe()
# Out:
# count     16598
# unique      494
# top           0
# freq       4443
# Name: NA_Sales, dtype: object

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df['Year'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 16593     True
# 16594     True
# 16595     True
# 16596     True
# 16597     True
# Name: Year, Length: 16598, dtype: bool

# %%
df[df['Year'] < 50].sort_values(by='Year', ascending=True)
# Out:
#                                          Name Platform  Year     Genre  \
# 16394                           Point Blank 3       PS   0.0   Shooter
# 9276                Trade & Battle: Card Hero       GB   0.0  Strategy
# 14666                               Strider 2       PS   0.0  Platform
# 2249                               SplashDown      PS2   1.0    Racing
# 8681                       NCAA Football 2002      PS2   1.0    Sports
# ...                                       ...      ...   ...       ...
# 11263                           Assetto Corsa      PS4  16.0    Racing
# 6192      Azure Striker Gunvolt: Striker Pack      3DS  16.0    Action
# 15447      Jikkyou Powerful Pro Baseball 2016      PSV  16.0    Sports
# 4010               Uncharted 4: A Thief's End      PS4  16.0   Shooter
# 8191   Super Robot Wars OG: The Moon Dwellers      PS3  16.0      Misc
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# ...

# %%
df[(df['Year'] < 10) == True]
# Out:
#                                                     Name Platform  Year  \
# 71               Age of Empires III: Complete Collection       PC   9.0
# 752                                  NASCAR Thunder 2004      PS2   3.0
# 994                                          Wolfenstein       PC   9.0
# 1197                     Ratchet & Clank: Going Commando      PS2   3.0
# 1336             LEGO Star Wars II: The Original Trilogy      PS2   6.0
# 1381                                       Rogue Warrior      PS3   9.0
# 1648   SpongeBob SquarePants featuring Nicktoons: Glo...      PS2   8.0
# 2196                                          SplashDown      PS2   1.0
# 2397             SOCOM: U.S. Navy SEALs Fireteam Bravo 2      PSP   6.0
# 2410                            Splat Renegade Paintball       XB   5.0
# 2484                     The SpongeBob SquarePants Movie       XB   4.0
# 2776           Naruto Shippuden: Dragon Blade Chronicles      Wii   9.0
# ...

# %%
not_in_200 = df[(df['Year'] < 10) == True]

# %%
not_in_200.Year = '200' + not_in_200.Year.astype('str')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
not_in_200.Year = not_in_200.Year.astype('float')

# %%
df[df['Year'] < 10] = not_in_200

# %%
df.Year.loc[15945]
# Out:
# 2000.0

# %%
df[(df['Year'] < 50) == True]
# Out:
#                                                     Name Platform  Year  \
# 208                                     NASCAR Unleashed      PS3  11.0
# 297         Kung Fu Panda: Showdown of Legendary Legends      PS3  15.0
# 2949                       Toaru Kagaku no Chou Denjihou      PSP  11.0
# 2972                       Kamen Rider Battle: Ganbaride       DS  10.0
# 3906                          Uncharted 4: A Thief's End      PS4  16.0
# 4204     Gunblade NY & L.A. Machineguns Arcade Hits Pack      Wii  10.0
# 4597                                            NBA 2K15      PS4  14.0
# 5050                                     Omega Labyrinth      PSV  15.0
# 5788                                          F.E.A.R. 3     X360  11.0
# 5951                      Kingdom Hearts: Birth by Sleep      PSP  10.0
# 5995                                               Brink     X360  11.0
# 6027                 Azure Striker Gunvolt: Striker Pack      3DS  16.0
# ...

# %%
df.Year
# Out:
# 0        2008.0
# 1        2009.0
# 2        2010.0
# 3        2010.0
# 4        2010.0
#           ...
# 16593    2006.0
# 16594    2005.0
# 16595    2015.0
# 16596    2013.0
# 16597    1996.0
# Name: Year, Length: 16598, dtype: float64

# %%
not_in_20 = df[(df['Year'] < 50) == True]

# %%
not_in_20.Year = '20' + not_in_20.Year.astype('str')

# %%
not_in_20.Year = not_in_20.Year.astype('float')

# %%
df[df['Year'] < 50] = not_in_20

# %%
df.Year.loc[15401]
# Out:
# 2015.0

# %%
df[(df['Year'] < 100) == True]
# Out:
#                                             Name Platform  Year      Genre  \
# 78                         Treasures of the Deep       PS  97.0     Action
# 887    Mini-Yonku Shining Scorpion: Let's & Go!!     SNES  96.0     Racing
# 2372                                      Casper       PS  96.0  Adventure
# 3404                                      Glover      N64  98.0   Platform
# 4249                            Adventure Island      NES  86.0   Platform
# 4675                                  Virtua Cop      SAT  95.0    Shooter
# 4707                          Mobile Suit Gundam       PS  95.0     Action
# 10051                       AeroFighters Assault      N64  97.0     Action
# 10427                                3D Baseball       PS  96.0     Sports
# 11036                  Super Fire ProWrestling X     SNES  95.0   Fighting
# 14173                                  S.C.A.R.S       PS  98.0     Racing
# ...

# %%
not_in_19 = df[(df['Year'] < 100) == True]

# %%
not_in_19.Year = '19' + not_in_19.Year.astype('str')

# %%
not_in_19.Year = not_in_19.Year.astype('float')

# %%
df[df['Year'] < 100] = not_in_19

# %%
df.Year.loc[16028]
# Out:
# 1998.0

# %%
df.Year
# Out:
# 0        2008.0
# 1        2009.0
# 2        2010.0
# 3        2010.0
# 4        2010.0
#           ...
# 16136    2006.0
# 16137    2005.0
# 16138    2015.0
# 16139    2013.0
# 16140    1996.0
# Name: Year, Length: 16141, dtype: float64

# %%
df.Year
# Out:
# 0        2008.0
# 1        2009.0
# 2        2010.0
# 3        2010.0
# 4        2010.0
#           ...
# 16593    2006.0
# 16594    2005.0
# 16595    2015.0
# 16596    2013.0
# 16597    1996.0
# Name: Year, Length: 16142, dtype: float64

# %% [markdown]
# 여기까지 Year column에서 일부 앞에 19, 20이 제외되어 있는 값을 채워서 넣음

# %%
df[df['NA_Sales'].str.contains('K')].NA_Sales.unique()
# Out:
# array(['480K', '60K', '0K', '490K', '240K', '150K', '4100K', '20K', '30K',
#        '50K', '70K', '190K', '1210K', '1610K', '100K', '170K', '40K',
#        '450K', '220K', '310K', '820K', '80K', '290K', '130K', '120K',
#        '1780K', '2930K', '10K', '280K', '540K', '550K', '2010K', '770K',
#        '340K', '90K', '600K', '2570K', '270K', '420K', '720K', '470K',
#        '320K'], dtype=object)

# %%
df_NA_K = df[df.iloc[:,5:10].NA_Sales.str.contains('K') == True]

# %%
df_NA_K.NA_Sales = df_NA_K.NA_Sales.str.extract('(\d+)').astype('int') / 1000

# %%
df[df.iloc[:,5:10].NA_Sales.str.contains('K') == True] = df_NA_K

# %%
df[df.iloc[:,5:10].NA_Sales.str.contains('K') == True]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df_EU_K = df[df.iloc[:,5:10].EU_Sales.str.contains('K') == True]

# %%
df_EU_K.EU_Sales = df_EU_K.EU_Sales.str.extract('(\d+)').astype('int') / 1000
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df[df.iloc[:,5:10].EU_Sales.str.contains('K') == True] = df_EU_K

# %%
df_JP_K = df[df.iloc[:,5:10].JP_Sales.str.contains('K') == True]
df_JP_K.JP_Sales = df_JP_K.JP_Sales.str.extract('(\d+)').astype('int') / 1000
df[df.iloc[:,5:10].JP_Sales.str.contains('K') == True] = df_JP_K

# %%
df_Other_K = df[df.iloc[:,5:10].Other_Sales.str.contains('K') == True]
df_Other_K.Other_Sales = df_Other_K.Other_Sales.str.extract('(\d+)').astype('int') / 1000
df[df.iloc[:,5:10].Other_Sales.str.contains('K') == True] = df_Other_K

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df.loc[df.NA_Sales.str.contains('M') == True]
# Out:
#                                              Name Platform    Year     Genre  \
# 436                    Medal of Honor: Warfighter     X360  2012.0    Action
# 447                                       F1 2010      PS3  2010.0    Racing
# 565                                 Mario Kart 64      N64  1996.0    Racing
# 611                                    The Hobbit      GBA  2003.0  Platform
# 658    Star Wars The Clone Wars: Lightsaber Duels      Wii  2008.0    Action
# ...                                           ...      ...     ...       ...
# 15549                 Juiced 2: Hot Import Nights       PC  2007.0    Racing
# 15708                       Taiko no Tatsujin Wii      Wii  2008.0      Misc
# 15724                    Medal of Honor: Airborne     X360  2007.0   Shooter
# 15957               NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16028            Super Robot Taisen F Kanketsuhen      SAT  1998.0  Strategy
#
# ...

# %%
df_NA_M = df.loc[df.NA_Sales.str.contains('M') == True]

# %%
df_NA_M.NA_Sales = df_NA_M.NA_Sales.str.extract('(\d+.\d+)').astype('float')

# %%
df_NA_M
# Out:
#                                              Name Platform    Year     Genre  \
# 436                    Medal of Honor: Warfighter     X360  2012.0    Action
# 447                                       F1 2010      PS3  2010.0    Racing
# 565                                 Mario Kart 64      N64  1996.0    Racing
# 611                                    The Hobbit      GBA  2003.0  Platform
# 658    Star Wars The Clone Wars: Lightsaber Duels      Wii  2008.0    Action
# ...                                           ...      ...     ...       ...
# 15549                 Juiced 2: Hot Import Nights       PC  2007.0    Racing
# 15708                       Taiko no Tatsujin Wii      Wii  2008.0      Misc
# 15724                    Medal of Honor: Airborne     X360  2007.0   Shooter
# 15957               NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16028            Super Robot Taisen F Kanketsuhen      SAT  1998.0  Strategy
#
# ...

# %%
df_NA_M.NA_Sales = df_NA_M.NA_Sales.fillna(0)

# %%
df.loc[df.NA_Sales.str.contains('M') == True] = df_NA_M

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df_EU_M = df.loc[df.EU_Sales.str.contains('M') == True]
df_EU_M.EU_Sales = df_EU_M.EU_Sales.str.extract('(\d+.\d+)').astype('float')
df_EU_M.EU_Sales = df_EU_M.EU_Sales.fillna(0)
df.loc[df.EU_Sales.str.contains('M') == True] = df_EU_M

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df_JP_M = df.loc[df.JP_Sales.str.contains('M') == True]
df_JP_M.JP_Sales = df_JP_M.JP_Sales.str.extract('(\d+.\d+)').astype('float')
df_JP_M.JP_Sales = df_JP_M.JP_Sales.fillna(0)
df.loc[df.JP_Sales.str.contains('M') == True] = df_JP_M

# %%
df.loc[df.Other_Sales.str.contains('M') == True]
# Out:
#                                                     Name Platform    Year  \
# 61                                       SD Gundam Force      GBA  2004.0
# 70                          Teenage Mutant Ninja Turtles       XB  2003.0
# 205                Harry Potter and the Sorcerer's Stone       XB  2003.0
# 215            Dragon Quest IV: Michibikareshi Monotachi       PS  2001.0
# 238                   Seaman 2: Peking Genjin Ikusei Kit      PS2  2007.0
# ...                                                  ...      ...     ...
# 15561                          Pro Yakyuu Family Stadium      NES  1986.0
# 15599                                      Point Blank 2       PS  1998.0
# 15634                     The Black Eyed Peas Experience      Wii  2011.0
# 15698  World Championship Poker: Featuring Howard Led...      PS2  2006.0
# 15961  Yu-Gi-Oh! Ultimate Masters: World Championship...      GBA  2006.0
#
#               Genre                     Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df_Other_M = df.loc[df.Other_Sales.str.contains('M') == True]
df_Other_M.Other_Sales = df_Other_M.Other_Sales.str.extract('(\d+.\d+)').astype('float')
df_Other_M.Other_Sales = df_Other_M.Other_Sales.fillna(0)
df.loc[df.Other_Sales.str.contains('M') == True] = df_Other_M

# %%
df.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# dtype: int64

# %%
df.loc[df.Other_Sales.str.contains('M') == True]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df
# Out:
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16136                         Ice Age 2: The Meltdown       GC  2006.0
# 16137                     Rainbow Islands: Revolution      PSP  2005.0
# 16138                                        NBA 2K16      PS3  2015.0
# 16139                     Toukiden: The Age of Demons      PSV  2013.0
# 16140                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.NA_Sales = df.NA_Sales.astype('float')
df.EU_Sales = df.EU_Sales.astype('float')
df.JP_Sales = df.JP_Sales.astype('float')
df.Other_Sales = df.Other_Sales.astype('float')

# %%
df['Global_Sales'] =  df['NA_Sales'] + df['EU_Sales'] + df['JP_Sales'] + df['Other_Sales']

# %%
df['Global_Sales'].head()
# Out:
# 0    0.04
# 1    0.18
# 2    0.02
# 3    0.04
# 4    0.25
# Name: Global_Sales, dtype: float64

# %%
df_A = df.groupby('Genre')['NA_Sales'].mean()

# %%
df_E = df.groupby('Genre')['EU_Sales'].mean()
df_J = df.groupby('Genre')['JP_Sales'].mean()
df_O = df.groupby('Genre')['Other_Sales'].mean()

# %%
df_A[0]
# Out:
# 0.2663839701770736

# %%
df_A_Sales = []
df_E_Sales = []
df_J_Sales = []
df_O_Sales = []

for i in df_A.index:
  df_A_Sales.append(df_A[i])
print(df_A_Sales)

for i in df_E.index:
  df_E_Sales.append(df_E[i])
print(df_E_Sales)

for i in df_J.index:
  df_J_Sales.append(df_J[i])
print(df_J_Sales)

for i in df_O.index:
  df_O_Sales.append(df_O[i])
print(df_O_Sales)
# Out:
# [0.2663839701770736, 0.0810223642172524, 0.26420863309352516, 0.23656249999999998, 0.5129953917050691, 0.21898916967509025, 0.29210873146622734, 0.21924033149171268, 0.45005485893416924, 0.216726403823178, 0.29124562937062937, 0.10308510638297871]
# [0.15947777432390425, 0.05090472377902322, 0.12007211538461539, 0.12503315250150693, 0.2309331797235023, 0.09083182640144664, 0.192668863261944, 0.1261256906077348, 0.24291307752545027, 0.1342330558858502, 0.1619650655021834, 0.06755287009063445]
# [0.048464652756150736, 0.0410853950518755, 0.10468749999999999, 0.06300847457627119, 0.15090173410404625, 0.10177536231884057, 0.046236559139784944, 0.2352548209366391, 0.029968602825745684, 0.07573301549463647, 0.05913119789381307, 0.07405731523378582]
# ...

# %%
labelA =  df_A.index
labelE =  df_E.index
labelJ =  df_J.index
labelO =  df_O.index


plt.figure(figsize=(40, 40))
plt.subplot(4, 1, 1)
plt.pie(df_A_Sales, labels=labelA, autopct='%.1f%%')
plt.title('Pie America Chart of Market Share', fontsize=20)
plt.subplot(4, 1, 2)
plt.pie(df_E_Sales, labels=labelE, autopct='%.1f%%')
plt.title('Pie Europe Chart of Market Share', fontsize=20)
plt.subplot(4, 1, 3)
plt.pie(df_J_Sales, labels=labelJ, autopct='%.1f%%')
plt.title('Pie Japan Chart of Market Share', fontsize=20)
plt.subplot(4, 1, 4)
plt.pie(df_O_Sales, labels=labelO, autopct='%.1f%%')
plt.title('Pie Other Country Chart of Market Share', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pie Other Country Chart of Market Share')

# %% [markdown]
# 지역에 따라서 선호하는 게임 장르가 다를까 라는 질문에 대답을 하셔야합니다.
#
# 1.지역은 어떻게 구분했나요?
# => 각 지역에 따른 출고량에 따라 지역별로 구분함
#
# 2.지역별로 선호하는 게임의 장르를 파악했나요?
# => 지역별로 선호하는 지역은 출고량에 퍼센테이지가 1순위로 정함
#
# 미국: 플랫폼, 유럽: shooter, 일본 : Role-Playing, 다른 여타 국가 : shooter
#
# 3.지역별로 선호하는 게임의 장르가 왜 같다고/다르다고 생각했나요?
#
# 각 나라 별로 선호하는 장르는 따로 있고 이러한 선호한 인기에 따라 출고량이 나타나기 때문에 선호 장르는 다르다고 생각함

# %%
df_sort.Genre.unique()
# Out:
# array(['Shooter', 'Misc', 'Action', 'Fighting', 'Sports', 'Puzzle',
#        'Racing', 'Platform', 'Simulation', 'Adventure', 'Role-Playing',
#        'Strategy'], dtype=object)

# %%
Year_list = df.Year.sort_values().unique()

# %%
Global_S_2016 = []
Genre_2016_list = df[df['Year'] == 2016].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales.index

for i in range(len(Genre_2016_list)):
  Glo_G = df[df['Year'] == 2016].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales[i]
  Global_S_2016.append(Glo_G)
print(Global_S_2016)
# Out:
# [0.5678124999999999, 0.385, 0.275, 0.20800000000000002, 0.17051282051282052, 0.1694017094017094, 0.08349999999999999, 0.0638888888888889, 0.056451612903225805, 0.052000000000000005, 0.043333333333333335]

# %%
df_2000.groupby(['Year', 'Genre'])['Global_Sales'].mean().reset_index()
# Out:
#        Year         Genre  Global_Sales
# 0    2001.0        Action      0.858788
# 1    2001.0     Adventure      0.448000
# 2    2001.0      Fighting      1.005556
# 3    2001.0          Misc      0.630385
# 4    2001.0      Platform      0.933095
# ..      ...           ...           ...
# 189  2016.0        Sports      0.385000
# 190  2016.0      Strategy      0.052000
# 191  2017.0        Action      0.010000
# 192  2017.0  Role-Playing      0.020000
# 193  2020.0    Simulation      0.290000
#
# [194 rows x 3 columns]

# %%
df.groupby(['Year', 'Genre']).agg({'Global_Sales' : ['max']})
# Out:
#                     Global_Sales
#                              max
# Year   Genre
# 1980.0 Action               0.34
#        Fighting             0.77
#        Misc                 1.15
#        Shooter              4.31
# 1981.0 Action               2.20
# ...                          ...
# 2016.0 Sports               4.78
#        Strategy             0.21
# 2017.0 Action               0.01
#        Role-Playing         0.03
# 2020.0 Simulation           0.29
#
# [388 rows x 1 columns]

# %%
Glo_15 = df[df['Year'] == 2015].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales
Glo_16 = df[df['Year'] == 2016].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales

# %%
Year_list
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2020.])

# %%
df[df['Year'] == 2000].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales.index
# Out:
# Role-Playing    1
# Action          1
# Misc            1
# Fighting        1
# Platform        1
# Strategy        1
# Sports          1
# Racing          1
# Shooter         1
# Puzzle          1
# Simulation      1
# Adventure       1
# Name: Genre, dtype: int64

# %%
Year_len = []
for i in Year_list:
   Yy = len(df[df['Year'] == i].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales.index)
   Year_len.append(Yy)
print(Year_len)
# Out:
# [4, 7, 7, 7, 7, 7, 6, 7, 8, 7, 7, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 11, 2, 1]

# %%
len(Year_len)
# Out:
# 39

# %%
print(Year_len)
# Out:
# 1

# %%
df_Y = df.groupby(['Year','Genre'])['Global_Sales'].mean().reset_index()

# %%
df_Y
# Out:
#        Year         Genre  Global_Sales
# 0    1980.0        Action      0.340000
# 1    1980.0      Fighting      0.770000
# 2    1980.0          Misc      0.675000
# 3    1980.0       Shooter      3.535000
# 4    1981.0        Action      0.604167
# ..      ...           ...           ...
# 383  2016.0        Sports      0.385000
# 384  2016.0      Strategy      0.052000
# 385  2017.0        Action      0.010000
# 386  2017.0  Role-Playing      0.020000
# 387  2020.0    Simulation      0.290000
#
# [388 rows x 3 columns]

# %%
Y = df_Y.pivot(index='Year', columns='Genre', values='Global_Sales').fillna(0)

# %%
Y.columns.unique()
# Out:
# Index(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
#        'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'],
#       dtype='object', name='Genre')

# %%
Year_sum = Y.sum(axis=1).unique()

# %%
df_Sales = pd.DataFrame(columns=['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
       'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
       'Strategy'])

for i in range(39):
  Y2 = Y.iloc[i] / Year_sum[i]
  df_Sales = df_Sales.append(Y2)

# %%
df_Sales
# Out:
#           Action  Adventure  Fighting      Misc  Platform    Puzzle    Racing  \
# 1980.0  0.063910   0.000000  0.144737  0.126880  0.000000  0.000000  0.000000
# 1981.0  0.098193   0.000000  0.000000  0.000000  0.374895  0.182843  0.078013
# 1982.0  0.047138   0.000000  0.000000  0.113565  0.131318  0.436857  0.102470
# 1983.0  0.046404   0.045431  0.000000  0.243056  0.157418  0.088590  0.000000
# 1984.0  0.090369   0.000000  0.000000  0.070830  0.033705  0.051128  0.096882
# 1985.0  0.101120   0.000000  0.060327  0.000000  0.620080  0.046107  0.000000
# 1986.0  0.205059   0.000000  0.000000  0.000000  0.140139  0.000000  0.175509
# 1987.0  0.048953   0.386329  0.239030  0.000000  0.076736  0.000000  0.000000
# 1988.0  0.043890   0.000000  0.000000  0.000000  0.349729  0.281498  0.107958
# 1989.0  0.104549   0.000000  0.000000  0.057558  0.309675  0.339504  0.000000
# 1990.0  0.106482   0.000000  0.000000  0.000000  0.382936  0.149725  0.156224
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

ax = df_Sales.iloc[:10].plot(kind="barh", figsize=(25, 10), stacked=True, title="연도별 출고량에 따른 트렌드 % ", colormap='Paired', rot=0)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.1f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center', fontsize=8)
plt.box(False)
plt.show()

# %%
ax = df_Sales.iloc[10:20].plot(kind="barh", figsize=(25, 10), stacked=True, title="연도별 출고량에 따른 트렌드 % ", colormap='Paired', rot=0)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.1f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center', fontsize=8)
plt.box(False)
plt.show()

# %%
ax = df_Sales.iloc[20:30].plot(kind="barh", figsize=(25, 10), stacked=True, title="연도별 출고량에 따른 트렌드 % ", colormap='Paired', rot=0)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.1f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center', fontsize=8)
plt.box(False)
plt.show()

# %%
ax = df_Sales.iloc[30:39].plot(kind="barh", figsize=(25, 10), stacked=True, title="연도별 출고량에 따른 트렌드 % ", colormap='Paired', rot=0)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.1f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center', fontsize=8)
plt.box(False)
plt.show()

# %% [markdown]
# 연도별 게임의 트렌드가 있을까 라는 질문에 대답을 하셔야합니다.
#
# 트렌드는 어떤 것을 기준으로 파악했나요? 트렌드는 장르에 따라 파악함
#
# 연도별로 트렌드가 존재하나요? 연도별로 주목하는 장르가 매년 상이함
# 그리고 2017, 2020년 자료들 수가 부족하기 때문에 2017, 2020년은 제외함
#
# 왜 존재한다/존재하지 않는다고 생각했나요? 트렌드가 존재하는 이유는 매년마다 추구하는 장르가 달라지고 있다. 어떤 해는 shooter가 또 어떤 해는 Action이 따라서 각년마다 새 인기 장르도 달라지고 있음

# %%
Global_S_1980 = []

Genre_1980_list = df[df['Year'] == 1980].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales.index

for i in range(len(Genre_1980_list)):
  Glo_G_1980 = df[df['Year'] == 1980].groupby('Genre').mean().sort_values(by='Global_Sales', ascending=False).Global_Sales[i]
  Global_S_1980.append(Glo_G_1980)
print(Global_S_1980)
# Out:
# [3.5349999999999997, 0.77, 0.675, 0.34]

# %%
df_sort = df.sort_values(by='Global_Sales', ascending=False)

# %%
df.sort_values(by='Global_Sales', ascending=False).iloc[:40]
# Out:
#                                                Name Platform    Year  \
# 2841                                     Wii Sports      Wii  2006.0
# 4088                              Super Mario Bros.      NES  1985.0
# 12241                                Mario Kart Wii      Wii  2008.0
# 3269                              Wii Sports Resort      Wii  2009.0
# 7623                       Pokemon Red/Pokemon Blue       GB  1996.0
# 1180                                         Tetris       GB  1989.0
# 6753                          New Super Mario Bros.       DS  2006.0
# 2943                                       Wii Play      Wii  2006.0
# 16076                     New Super Mario Bros. Wii      Wii  2009.0
# 10215                                     Duck Hunt      NES  1984.0
# 10846                                    Nintendogs       DS  2005.0
# 10372                                 Mario Kart DS       DS  2005.0
# 9176                    Pokemon Gold/Pokemon Silver       GB  1999.0
# ...

# %%
df_wii = df_sort[df_sort['Platform'] == 'Wii']

# %%
np.random.seed(10)

nonin_means = []
nin_means = []
diff_means = []

for _ in range(10000):
  sample = df_wii.sample(df_wii.shape[0], replace=True)
  
  nin_mean = sample[sample['Publisher'] == 'Nintendo'].Global_Sales.mean()
  nin_means.append(nin_mean)

  nonin_mean = sample[sample['Publisher'] != 'Nintendo'].Global_Sales.mean()
  nonin_means.append(nonin_mean)

  diff_means.append(nin_mean - nonin_mean)

# %%
plt.figure(figsize=(8,5))
plt.hist(nonin_means, alpha = 0.5, label='no Nintendo')
plt.hist(nin_means, alpha = 0.5, label = 'Nintendo')
plt.legend(loc=9, fontsize=13)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(diff_means, alpha=0.5, label = 'Difference in Means')
plt.axvline(wii_mean, c='r')
plt.legend(loc=9, fontsize=13);

# %%
np.std(diff_means)
# Out:
# 1.2866333173065445

# %%
nin = df_wii[df_wii['Publisher'] == 'Nintendo'].Global_Sales
non = df_wii[df_wii['Global_Sales'] != 'Nintendo'].Global_Sales

# %%
from scipy.stats import ttest_ind

ttest_ind(nin, non, alternative='greater').pvalue
# Out:
# 4.8755872907142625e-17

# %% [markdown]
# 인기가 많은 게임에 대한 분석 및 시각화 프로세스가 포함되어야 합니다.
#
# 인기가 많다는 것을 어떻게 정의했나요? 출판사와 플랫폼을 기준으로 해당 출판사, 플랫폼을 기준으로 비교해 해당 데이터의 Global_Sales의 값이 더 높다면 인가가 많은 것으로 정함
#
# 해당 게임이 왜 인기가 많다고 생각했나요? 랜덤 포레스트를 사용해 중복추출을 허용해 출판사, 플랫폼을 기준으로 해당 출판사, 플랫폼을 비교해서 판단함
#
# 시각화를 통해 무엇을 나타내고자 하는지를 고려했나요? Nintendo, wii 데이터의 평균이 더 높은 것을 나타내고자 함. 위 시각화로 p-value 값을 판단할 수 있고 실제로 코드로 구현해 p-value가 낮은 값인지를 볼 수 있음
#
# 해당 분석을 통해 어떤 인사이트를 도출할 수 있나요?
# 동일 플랫폼을 비교해봤을 때 닌텐도 부분이 Global_Sales가 높은 것을 볼 수 있음
